# %% [markdown]
# https://github.com/mitmath/18338

# %%
using Plots

# %%
v = [.9, .9, 1.1, 1.1, 1.5, 1.9, 1.9, 2.1, 2.1, 2.5, 2.9, 2.9, 3.1, 3.1]
# Out:
# 14-element Array{Float64,1}:
#  0.9
#  0.9
#  1.1
#  1.1
#  1.5
#  1.9
#  1.9
#  2.1
#  2.1
#  2.5
#  2.9
#  2.9
#  3.1
#  3.1

# %% [markdown]
# # Histogram as plot

# %%
h=histogram(v,bins=.5:3.5, bar_width=.9)

# %% [markdown]
# # Normalized Histograms¶

# %%
@time v = randn(100000)
# Out:
#   0.001541 seconds (2 allocations: 781.328 KiB)
# 100000-element Array{Float64,1}:
#   0.6610047225369281
#  -0.873704712289904
#   0.10080144146281304
#   0.32999029175053307
#   1.079876672991836
#  -0.8491352083952155
#  -1.434718081844581
#  -1.5628106938860329
#  -0.5045300147322607
#  -1.1604431443962655
#   0.042181408418944355
#   2.4890577771642293
#  -0.4444911499656397
#   ⋮
#  -0.6201491735645828
#  -1.8161668843262755
#  -2.6661999313382445
#  -1.3163844875769872
#  -0.40218887536703
#  -0.8357607358645319
#   1.2757667989035177
#  -1.8869738868780541
#   0.7244349458663595
#  -0.8105709406242056
#  -1.4926770837316123
#   0.4874464625284553

# %%
histogram(v, normalize=true, legend=false)
